# %%
# Notebook makes data public publishing safe.
# Aim to remove email addresses and full names, replacing them with ID's and abbreviations.

# %%
import pandas as pd
import numpy as np
import os
import random
import string


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '0.0_Container for Events.ipynb',
#  '2025_Events_Planning.csv',
#  'Asana import and Clean.ipynb',
#  'asanaData.csv',
#  'asanaData_single.csv',
#  'asana_dates_clean.csv',
#  'Children_Master.csv',
#  'connection1',
#  'connectionTest',
#  'Engagment_counts.csv',
#  'Events',
#  'Family Futures EventTabling Feedback.csv',
#  'Image20250630140836.png',
#  'Local_asanaData.csv',
#  'Local_asanaData_single.csv',
#  'Local_Emails_Names.csv',
#  'Local_SurveyCompletions.csv',
#  'Local_surveyMonkey.csv',
#  'Private_Local to Public.ipynb',
#  'README.md',
#  'Reports',
#  'Survey Completion.ipynb',
#  'SurveyCompletions.csv',
#  'SurveyMonkey import and Clean.ipynb',
#  'surveyMonkey.csv',
#  'Tableau Events',
#  'test',
#  'Thumbs.db']

# %%
#getting all needed datasets
Emails_Names_raw = pd.read_csv('Local_Emails_Names.csv')
asanaData_single_cleaned = pd.read_csv('Local_asanaData_single.csv')
asanaData_cleaned = pd.read_csv('Local_asanaData.csv')
surveyMonkey_cleaned = pd.read_csv('Local_surveyMonkey.csv')
SurveyCompletions_report = pd.read_csv('Local_SurveyCompletions.csv')

# %%
Emails_Names_raw.head()
# Out:
#              Display name       Department         Username  \
# 0       Accounting and HR            Email  AccountingandHR
# 1           Adison Fryman            Staff          afryman
# 2  Administrator Template  Special Purpose              NaN
# 3        Adobe Software 1              NaN   AdobeSoftware1
# 4        Adobe Software 2              NaN   AdobeSoftware2
#
#                                Email
# 0  AccountingandHR@familyfutures.org
# 1          afryman@familyfutures.org
# 2                 @familyfutures.org
# 3                              FALSE
# 4                              FALSE

# %%
# Creating ID's with First letter of Department + zfill(5)
Emails_Names_raw["ID"] = (
    Emails_Names_raw["Department"].str[0].str.upper() #first letter of Department
    + (Emails_Names_raw.index + 1).astype(str).str.zfill(5) #sequential number starting at 1 with leading zeros
)

#creating fake usernames
# Split the name into first and last
name_split = Emails_Names_raw["Display name"].str.split(" ", n=1, expand=True)
first_name = name_split[0].str[:3]   # first 3 letters of first name
last_name = name_split[1].str[:3]    # first 3 letters of last name

# Combine into CodeName
Emails_Names_raw["CodeName"] = first_name + last_name

# Drop any Emails_Names_raw where ID or CodeName = NaN
Emails_Names_raw = Emails_Names_raw.dropna(subset=["ID", "CodeName"])

# %%
Emails_Names_raw
# Out:
#                        Display name                 Department  \
# 0                 Accounting and HR                      Email
# 1                     Adison Fryman                      Staff
# 2            Administrator Template            Special Purpose
# 10                    Adrianna Lynn  External Healthy Families
# 16                 Alissa Rodriguez  External Healthy Families
# 17                Allison Vriesenga  External Healthy Families
# 18                  Alyce Hernandez  External Healthy Families
# 19                   Alysse Calabio                     Intern
# 20                      Amanda Vins                      Staff
# 21                   Amelia Stanley  External Healthy Families
# 194                   Mariana Urrea                      Staff
# 195                    Marilyn Kehr                      Staff
# 196                  Matthew Selmon                      Staff
# 199              Melanie Caracciolo     Third Party Accounting
# 203                  Miguel Velasco                   External
# 205            Mobile User Template            Special Purpose
# 206                 Monica Marchell  External Healthy Families
# 211                   Nicole Harris                Staff-Board
# 215                  Olivia Trappen                      Staff
# 221                    Paige Fisher  External Healthy Families
# 224                   Patty Smalley                      Staff
# 226  Power User Disk Quota increase            Special Purpose
# 227             Power User Template            Special Purpose
# 232                      Rachel Fox  External Healthy Families
# 233                  Rachel Johnson             Staff-Board-HF
# 235                   Rachel Warner                      Staff
# 237                    Raisers Edge                      Email
# 239                    Rebecca Back  External Healthy Families
# 240                    Rebecca Boot                      Staff
# 241                 Rebekah Waalkes                      Staff
# 243               Rivertown Finance                   Contract
# 244          Roberta (Bobbi) Lareau                  Volunteer
# 250             Samantha Richardson                      Staff
# 251                    Sandy Portko                      Staff
# 252                      Sarah Hill                      Staff
# 253                  Sarah Matthews       External Connections
# 255                   Seth Vandever                  Volunteer
# 256                     Share Point            Special Purpose
# 260                      STS Worker            Special Purpose
# 261                  Sujatha Pillai                  Volunteer
# 262                  Sujatha Pillai                  Volunteer
# 263                    Susan Alonso                      Staff
# 264                     Susi Alonso                      Staff
# 265                    Tableau User            Special Purpose
# 266                    Tanya Zamora  External Healthy Families
# 273                      Test 365 2                      Staff
# 274                        Test 365                   Staff-IT
# 275                        Test Tes              FamilyFutures
# 280                   Teya Li Weber                     Intern
# 282                 Tiffany Cerrato                      Staff
# 283           Tikila Haywood-Camara  External Healthy Families
# 284                    Tony Racalla                      Staff
# 285                    Tonya Warren       External Connections
# 291                    Valeria Cano                      Staff
# 292                 Victoria Nasser                      Staff
# 294                      Wendy Cano                      Staff
# 296                        Zoom AHR                      Rooms
# 297                         Zoom FF                      Rooms
# 298                   Cara Sutliffe                        FAB
# 299           Christina Pocklington                        FAB
# 300                   Kayla Hopkins                        FAB
# 301                 Monique Vasquez                        FAB
# 302                    Tara Kuenzer                        FAB
# 303                    Ashley Ledon                        FAB
# 304                   Heather Carew                        FAB
# 305                  Richard Miller                        FAB
#
#                   Username                                    Email      ID  \
# 0          AccountingandHR        AccountingandHR@familyfutures.org  E00001
# 1                  afryman                afryman@familyfutures.org  S00002
# 2                      NaN                       @familyfutures.org  S00003
# 10                     NaN                       @familyfutures.org  E00011
# 16                     NaN                       @familyfutures.org  E00017
# 17                     NaN                       @familyfutures.org  E00018
# 18              ahernandez             ahernandez@familyfutures.org  E00019
# 19                acalabio               acalabio@familyfutures.org  I00020
# 20                   avins                  avins@familyfutures.org  S00021
# 21                     NaN                       @familyfutures.org  E00022
# 23                  alente                 alente@familyfutures.org  S00024
# 24                     NaN                       @familyfutures.org  E00025
# 26                     NaN                       @familyfutures.org  E00027
# 27                  acurry                 acurry@familyfutures.org  I00028
# 33         SBS_Backup_User        SBS_Backup_User@familyfutures.org  S00034
# 35                     NaN                       @familyfutures.org  E00036
# 172                 ltagle                 ltagle@familyfutures.org  S00173
# 174                  lpham                  lpham@familyfutures.org  I00175
# 175                ltejada                ltejada@familyfutures.org  S00176
# 176                    NaN                       @familyfutures.org  E00177
# 177               lhubbard               lhubbard@familyfutures.org  S00178
# 178                 lbrown                 lbrown@familyfutures.org  S00179
# 179                 lstone                 Lstone@familyfutures.org  S00180
# 180               ljoswick               ljoswick@familyfutures.org  S00181
# 181             lfernandez             lfernandez@familyfutures.org  S00182
# 182                 lwelch                 lwelch@familyfutures.org  C00183
# 183               mcollard               mcollard@familyfutures.org  I00184
# 184                 modell                 modell@familyfutures.org  T00185
# 186               mhoffman               mhoffman@familyfutures.org  S00187
# 187                    NaN                       @familyfutures.org  V00188
# 190               mthomson               mthomson@familyfutures.org  I00191
# 192                    NaN                       @familyfutures.org  E00193
# 193                  mlara                  mlara@familyfutures.org  S00194
# 194                 murrea                 murrea@familyfutures.org  S00195
# 195                  mkehr                  mkehr@familyfutures.org  S00196
# 196                mselmon                mselmon@familyfutures.org  S00197
# 199               melaniec               melaniec@familyfutures.org  T00200
# 203                    NaN                       @familyfutures.org  E00204
# 205                    NaN                       @familyfutures.org  S00206
# 206                    NaN                       @familyfutures.org  E00207
# 211                nharris                nharris@familyfutures.org  S00212
# 215               otrappen               otrappen@familyfutures.org  S00216
# 221                pfisher                pfisher@familyfutures.org  E00222
# 224               psmalley               psmalley@familyfutures.org  S00225
# 226                    NaN                       @familyfutures.org  S00227
# 227                    NaN                       @familyfutures.org  S00228
# 232                    NaN                       @familyfutures.org  E00233
# 233               rjohnson               rjohnson@familyfutures.org  S00234
# 235                rwarner                rwarner@familyfutures.org  S00236
# 237                REadmin                REadmin@familyfutures.org  E00238
# 239                    NaN                       @familyfutures.org  E00240
# 240                  rboot                  rboot@familyfutures.org  S00241
# 241               rwaalkes               rwaalkes@familyfutures.org  S00242
# 243                    NaN                       @familyfutures.org  C00244
# 244                rlareau                rlareau@familyfutures.org  V00245
# 250            srichardson            srichardson@familyfutures.org  S00251
# 251                sportko                sportko@familyfutures.org  S00252
# 252                  shill                  shill@familyfutures.org  S00253
# 253                    NaN                       @familyfutures.org  E00254
# 255           sethvandever           sethvandever@familyfutures.org  V00256
# 256             sharepoint             sharepoint@familyfutures.org  S00257
# 260                    NaN                       @familyfutures.org  S00261
# 261              s_rpillai              s_rpillai@familyfutures.org  V00262
# 262                    NaN                       @familyfutures.org  V00263
# 263                    NaN                salonso@familyfutures.org  S00264
# 264                salonso                salonso@familyfutures.org  S00265
# 265                    NaN                       @familyfutures.org  S00266
# 266                    NaN                       @familyfutures.org  E00267
# 273          KGBCASauditor          KGBCASauditor@familyfutures.org  S00274
# 274                   T365                   T365@familyfutures.org  S00275
# 275                    NaN                       @familyfutures.org  F00276
# 280               tliweber                 tweber@familyfutures.org  I00281
# 282               tcerrato               tcerrato@familyfutures.org  S00283
# 283                    NaN                       @familyfutures.org  E00284
# 284               tracalla               tracalla@familyfutures.org  S00285
# 285                    NaN                       @familyfutures.org  E00286
# 291                  vcano                  vcano@familyfutures.org  S00292
# 292                vnasser                vnasser@familyfutures.org  S00293
# 294                  wcano                  wcano@familyfutures.org  S00295
# 296                    NaN                       @familyfutures.org  R00297
# 297                    NaN                       @familyfutures.org  R00298
# 298                    NaN                    carajeannie@gmail.com  F00299
# 299                    NaN                    cldaugherty@gmail.com  F00300
# 300                    NaN                 kayla.smith689@gmail.com  F00301
# 301                    NaN            moniquevasquez@email.grcc.edu  F00302
# 302                    NaN                    tarakuenzer@gmail.com  F00303
# 303                    NaN                    wrightash08@gmail.com  F00304
# 304                    NaN                joyfulharmonies@gmail.com  F00305
# 305                    NaN             richard.miller0215@gmail.com  F00306
#
#     CodeName
# 0     Accand
# 1     AdiFry
# 2     AdmTem
# 10    AdrLyn
# 16    AliRod
# 17    AllVri
# 18    AlyHer
# 19    AlyCal
# 20    AmaVin
# 21    AmeSta
# 23    AmyLen
# 24    AndMon
# 26    AngRic
# 27    AnnCur
# 33    BacUse
# 35    BarHat
# 40    BraAle
# 41    BraAle
# 42    BraRey
# 44    BriTur
# 46    BroAer
# 47     C2Onn
# 48    CamSim
# 49    CanCow
# 52    ChaFor
# 53    CheKno
# 54    Chiand
# 59    ComEdu
# 61    ConRoo
# 62    ConRoo
# 63    ConRoo
# 64    ConACE
# 66    CorHol
# 67    CriRod
# 68    CylBli
# 69    DalVan
# 70    DalVan
# 71    DavMcC
# 77    EarKen
# 78    EboLuc
# 79    EliNel
# 80    EllCat
# 81    EllJoh
# 83    ELNRep
# 84    EmiDom
# 85    EmiVan
# 87    EriWin
# 88    EriPoi
# 93    FamFut
# 94    FamRes
# 98    GabNye
# 101   GraLar
# 105   HanBel
# 108   HilBoe
# 117    HVAlg
# 118    HVRef
# 127   JaiClo
# 131    JDDan
# 135   JilUng
# 139   JohGeb
# 141   JolCla
# 144   JulSch
# 145   KarMon
# 149   KatMoo
# 150   KelRon
# 157   KolMit
# 159   KriHum
# 161   LanGou
# 164   LauCam
# 166   LauBri
# 167   LeaPaa
# 170   LesSor
# 171   LetMir
# 172   LiaTag
# 174   LilPha
# 175   LinTej
# 176   LinGen
# 177   LinHub
# 178   LisBro
# 179   LorSto
# 180   LucJos
# 181   LuiFer
# 182   LynWel
# 183   MadCol
# 184   MadO'd
# 186   MaiHof
# 187   MakSan
# 190   MarTho
# 192   MarMor
# 193   MarLar
# 194   MarUrr
# 195   MarKeh
# 196   MatSel
# 199   MelCar
# 203   MigVel
# 205   MobUse
# 206   MonMar
# 211   NicHar
# 215   OliTra
# 221   PaiFis
# 224   PatSma
# 226   PowUse
# 227   PowUse
# 232   RacFox
# 233   RacJoh
# 235   RacWar
# 237   RaiEdg
# 239   RebBac
# 240   RebBoo
# 241   RebWaa
# 243   RivFin
# 244   Rob(Bo
# 250   SamRic
# 251   SanPor
# 252   SarHil
# 253   SarMat
# 255   SetVan
# 256   ShaPoi
# 260   STSWor
# 261   SujPil
# 262   SujPil
# 263   SusAlo
# 264   SusAlo
# 265   TabUse
# 266   TanZam
# 273   Tes365
# 274   Tes365
# 275   TesTes
# 280   TeyLi
# 282   TifCer
# 283   TikHay
# 284   TonRac
# 285   TonWar
# 291   ValCan
# 292   VicNas
# 294   WenCan
# 296   ZooAHR
# 297    ZooFF
# 298   CarSut
# 299   ChrPoc
# 300   KayHop
# 301   MonVas
# 302   TarKue
# 303   AshLed
# 304   HeaCar
# 305   RicMil

# %%
#Section 2
        # removing private information from files

# %%
# 1: asanaData_single_cleaned

asanaData_single_cleaned.head(20)
#columns to adjust:
#'Assignee'-its full name, change to code name

# Create a mapping from Display name → CodeName
name_to_code = dict(zip(Emails_Names_raw["Display name"], Emails_Names_raw["CodeName"]))

# Replace Assignee names with CodeName
asanaData_single_cleaned["Assignee"] = asanaData_single_cleaned["Assignee"].map(name_to_code)


#asanaData_single_cleaned.head()
asanaData_single_cleaned.to_csv('asanaData_single.csv')

# %%
# 2: asanaData_cleaned


Columns_to_Remove_names = {   'Staff Attending',
 'FAB Attending',
 'Intern(s) Attending',
 'Volunteers Attending',
 "Assignee"                  
       }

#asanaData_cleaned = asanaData_cleaned.drop(Columns_to_Remove, axis = 1)

# Create a mapping from Display name → CodeName
name_to_code = dict(zip(Emails_Names_raw["Email"], Emails_Names_raw["CodeName"]))

def map_names_to_codes(cell):
    if isinstance(cell, list):
        return [name_to_code.get(n.strip(), n) for n in cell]
    elif pd.isna(cell) or cell == "":
        return cell
    else:  # assume it's a comma-separated string
        names = [n.strip() for n in cell.split(",")]
        return [name_to_code.get(n, n) for n in names]

# Apply to all columns in the set that exist in the dataframe
for col in Columns_to_Remove_names:
    if col in asanaData_cleaned.columns:
        asanaData_cleaned[col] = asanaData_cleaned[col].apply(map_names_to_codes)


asanaData_cleaned.head(20)

#asanaData_single_cleaned.head()
asanaData_cleaned.to_csv('asanaData.csv')

# %%
# 3: surveyMonkey_cleaned

Columns_to_Remove2 = {'First Name','Last Name', 'Email'}

surveyMonkey_cleaned = surveyMonkey_cleaned.drop(Columns_to_Remove2, axis = 1)

# Create a mapping from Display name → CodeName
name_to_code = dict(zip(Emails_Names_raw["Display name"], Emails_Names_raw["CodeName"]))

# Replace Assignee names with CodeName
surveyMonkey_cleaned["Person Name"] = surveyMonkey_cleaned["Person Name"].map(name_to_code)


# create fake email from CodeName- bunch of NaN's 

surveyMonkey_cleaned['Email'] = surveyMonkey_cleaned['Person Name']+'@FamilyFutures.org'


surveyMonkey_cleaned.to_csv('surveyMonkey.csv')

# %%
# 4: SurveyCompletions_report
Columns_to_Remove3 = {'First Name','Last Name', 'Attending Email','Email','Email SM','Unnamed: 0','Username'}
SurveyCompletions_report = SurveyCompletions_report.drop(Columns_to_Remove3, axis = 1)


# Create a mapping from Display name → CodeName
name_to_code = dict(zip(Emails_Names_raw["Display name"], Emails_Names_raw["CodeName"]))

# Replace Assignee names with CodeName
SurveyCompletions_report["Display name"] = SurveyCompletions_report["Display name"].map(name_to_code)
#SurveyCompletions_report.head(25)
SurveyCompletions_report.to_csv('SurveyCompletions.csv')
